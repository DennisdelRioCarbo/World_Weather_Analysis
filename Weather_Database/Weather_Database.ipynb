# %%
import pandas as pd

import numpy as np

from citipy import citipy

import time

import requests

from config import weather_api_key

# %%
#Create a set of random latitude and longitude combinations.

lats=np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs=np.random.uniform(low=-180.000, high=180.00, size=2000)

lat_lngs=zip(lats,lngs)

coordinates=list(lat_lngs)

#Create a list for holding the cities.

cities=[]

#Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique, them we will add it to the cities list.
    
    if city not in cities:
        
        cities.append(city)
        
#Print the city count to confirm sufficient count.

len(cities)
# Out:
# 735

# %%
url="https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid="+ weather_api_key

#Create an empty list to hold the weather data.

city_data = []

#Print the beginning of the logging.

print("Beginning Data Retrieval     ")

print("-----------------------------")


#Create counters.

record_count=1

set_count=1

#Loop thrrough allthe cities in our list.

for i, city in enumerate(cities): 
    
    #Group cities in seats of 50 for logging purposes.
    
    if (i % 50==0 and i >= 50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)
        
     #Create endpoint URL with each city.
        
    city_url=url + "&q=" + city.replace(" ", "+")
    
    
    #log th Url, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count.
    
    record_count +=1
    
 #Run an API request for each of the cities.

    try:

        #Parse the JSON and retrieve data.
        
        city_weather=requests.get(city_url).json()
        
        #Parse out the needed data.
        
        city_lat=city_weather["coord"]["lat"]
        
        city_lng=city_weather["coord"]["lon"]
        
        city_max_temp=city_weather["main"]["temp_max"]
        
        city_humidity=city_weather["main"]["humidity"]
        
        city_clouds=city_weather["clouds"]["all"]
        
        city_wind=city_weather["wind"]["speed"]
        
        city_country=city_weather["sys"]["country"]
        
        city_weather_description=city_weather["weather"][0]["description"]
        
        #Append the city information into city_data list.
        
        city_data.append({"City":city.title(), "Lat":city_lat, "Lng":city_lng, "Max Temp":city_max_temp, "Humidity":city_humidity, "Cloudiness":city_clouds, "Wind Speed":city_wind, "Country":city_country, "Current Description":city_weather_description})
        
        #If an error is experienced, skip the city.
        
    except:
        
        print("City not found. Skipping ...")
        
        pass
    
#Indicate that Data Loading is complete.

print("--------------------------------")

print("Data Retrieval Complete         ")

print("--------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | high level
# Processing Record 3 of Set 1 | moron
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | saint george
# Processing Record 6 of Set 1 | egvekinot
# Processing Record 7 of Set 1 | kavieng
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping ...
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | zabid
# Processing Record 12 of Set 1 | dudinka
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | inuvik
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | gorkovskoye
# City not found. Skipping ...
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | talgar
# Processing Record 23 of Set 1 | namatanai
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | aklavik
# Processing Record 26 of Set 1 | callaway
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | hit
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | jeremie
# Processing Record 31 of Set 1 | richards bay
# Processing Record 32 of Set 1 | bambous virieux
# Processing Record 33 of Set 1 | hilo
# Processing Record 34 of Set 1 | mapastepec
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | lagoa
# Processing Record 38 of Set 1 | santa maria
# Processing Record 39 of Set 1 | nacala
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | saint austell
# Processing Record 43 of Set 1 | zhangye
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | kaitangata
# Processing Record 46 of Set 1 | nome
# Processing Record 47 of Set 1 | zavoronezhskoye
# Processing Record 48 of Set 1 | quatre cocos
# Processing Record 49 of Set 1 | toliary
# City not found. Skipping ...
# Processing Record 50 of Set 1 | palmer
# Processing Record 1 of Set 2 | port macquarie
# Processing Record 2 of Set 2 | punta cardon
# Processing Record 3 of Set 2 | turukhansk
# Processing Record 4 of Set 2 | faanui
# Processing Record 5 of Set 2 | saldanha
# Processing Record 6 of Set 2 | groningen
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | anito
# Processing Record 9 of Set 2 | beringovskiy
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | hluti
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | talnakh
# Processing Record 15 of Set 2 | bajram curri
# Processing Record 16 of Set 2 | mitsamiouli
# Processing Record 17 of Set 2 | naze
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping ...
# Processing Record 19 of Set 2 | grand river south east
# City not found. Skipping ...
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | puerto baquerizo moreno
# Processing Record 23 of Set 2 | udachnyy
# Processing Record 24 of Set 2 | luderitz
# Processing Record 25 of Set 2 | garowe
# Processing Record 26 of Set 2 | jacareacanga
# Processing Record 27 of Set 2 | kudahuvadhoo
# Processing Record 28 of Set 2 | cidreira
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | huarmey
# Processing Record 31 of Set 2 | ponta do sol
# Processing Record 32 of Set 2 | shenjiamen
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | halalo
# City not found. Skipping ...
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | jacksonville beach
# Processing Record 37 of Set 2 | lavrentiya
# Processing Record 38 of Set 2 | khasan
# Processing Record 39 of Set 2 | stromness
# Processing Record 40 of Set 2 | pevek
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | ajdabiya
# Processing Record 43 of Set 2 | rocha
# Processing Record 44 of Set 2 | narsaq
# Processing Record 45 of Set 2 | hayvoron
# Processing Record 46 of Set 2 | priyutnoye
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | olafsvik
# Processing Record 49 of Set 2 | cayenne
# Processing Record 50 of Set 2 | kushmurun
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | tautira
# Processing Record 4 of Set 3 | najran
# Processing Record 5 of Set 3 | atuona
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping ...
# Processing Record 10 of Set 3 | pangody
# Processing Record 11 of Set 3 | gombe
# Processing Record 12 of Set 3 | ahuimanu
# Processing Record 13 of Set 3 | karasjok
# Processing Record 14 of Set 3 | bengkulu
# Processing Record 15 of Set 3 | hauterive
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | tuggurt
# City not found. Skipping ...
# Processing Record 18 of Set 3 | coquimbo
# Processing Record 19 of Set 3 | kodiak
# Processing Record 20 of Set 3 | nizhneyansk
# City not found. Skipping ...
# Processing Record 21 of Set 3 | leningradskiy
# Processing Record 22 of Set 3 | belushya guba
# City not found. Skipping ...
# Processing Record 23 of Set 3 | stolin
# Processing Record 24 of Set 3 | oranjemund
# Processing Record 25 of Set 3 | zyryanka
# Processing Record 26 of Set 3 | solnechnyy
# Processing Record 27 of Set 3 | thompson
# Processing Record 28 of Set 3 | ribeira grande
# Processing Record 29 of Set 3 | odesskoye
# Processing Record 30 of Set 3 | hermanus
# Processing Record 31 of Set 3 | vazhiny
# Processing Record 32 of Set 3 | omsukchan
# Processing Record 33 of Set 3 | shache
# Processing Record 34 of Set 3 | wasilla
# Processing Record 35 of Set 3 | ambulu
# Processing Record 36 of Set 3 | darhan
# Processing Record 37 of Set 3 | airai
# Processing Record 38 of Set 3 | sungairaya
# Processing Record 39 of Set 3 | illoqqortoormiut
# City not found. Skipping ...
# Processing Record 40 of Set 3 | naryan-mar
# Processing Record 41 of Set 3 | moree
# Processing Record 42 of Set 3 | qena
# Processing Record 43 of Set 3 | mys shmidta
# City not found. Skipping ...
# Processing Record 44 of Set 3 | sitka
# Processing Record 45 of Set 3 | oistins
# Processing Record 46 of Set 3 | lorengau
# Processing Record 47 of Set 3 | bilibino
# Processing Record 48 of Set 3 | shenkursk
# Processing Record 49 of Set 3 | lincoln
# Processing Record 50 of Set 3 | waingapu
# Processing Record 1 of Set 4 | dingle
# Processing Record 2 of Set 4 | vancouver
# Processing Record 3 of Set 4 | provideniya
# Processing Record 4 of Set 4 | tumannyy
# City not found. Skipping ...
# Processing Record 5 of Set 4 | nurota
# Processing Record 6 of Set 4 | zhanatas
# City not found. Skipping ...
# Processing Record 7 of Set 4 | fairbanks
# Processing Record 8 of Set 4 | temaraia
# City not found. Skipping ...
# Processing Record 9 of Set 4 | lata
# Processing Record 10 of Set 4 | pangnirtung
# Processing Record 11 of Set 4 | nuevo casas grandes
# Processing Record 12 of Set 4 | yumen
# Processing Record 13 of Set 4 | new norfolk
# Processing Record 14 of Set 4 | coahuayana
# Processing Record 15 of Set 4 | sabang
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | jose de freitas
# Processing Record 18 of Set 4 | mackay
# Processing Record 19 of Set 4 | sagaing
# Processing Record 20 of Set 4 | sioux lookout
# Processing Record 21 of Set 4 | san carlos de bariloche
# Processing Record 22 of Set 4 | vaitupu
# City not found. Skipping ...
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | bereda
# Processing Record 26 of Set 4 | vila velha
# Processing Record 27 of Set 4 | revelstoke
# Processing Record 28 of Set 4 | wladyslawowo
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | lashio
# Processing Record 31 of Set 4 | berlevag
# Processing Record 32 of Set 4 | porto novo
# Processing Record 33 of Set 4 | georgetown
# Processing Record 34 of Set 4 | paraiso
# Processing Record 35 of Set 4 | flinders
# Processing Record 36 of Set 4 | grants pass
# Processing Record 37 of Set 4 | bathsheba
# Processing Record 38 of Set 4 | parana
# Processing Record 39 of Set 4 | nikolskoye
# Processing Record 40 of Set 4 | iqaluit
# Processing Record 41 of Set 4 | bac lieu
# Processing Record 42 of Set 4 | tazovskiy
# Processing Record 43 of Set 4 | arlit
# Processing Record 44 of Set 4 | budogoshch
# Processing Record 45 of Set 4 | korla
# Processing Record 46 of Set 4 | tete
# Processing Record 47 of Set 4 | norrtalje
# Processing Record 48 of Set 4 | olot
# Processing Record 49 of Set 4 | alofi
# Processing Record 50 of Set 4 | hamilton
# Processing Record 1 of Set 5 | severo-kurilsk
# Processing Record 2 of Set 5 | wanning
# Processing Record 3 of Set 5 | amderma
# City not found. Skipping ...
# Processing Record 4 of Set 5 | chuy
# Processing Record 5 of Set 5 | kununurra
# Processing Record 6 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 5 | boguchany
# Processing Record 8 of Set 5 | vanderhoof
# Processing Record 9 of Set 5 | zhigansk
# Processing Record 10 of Set 5 | minna
# Processing Record 11 of Set 5 | las vegas
# Processing Record 12 of Set 5 | mathbaria
# Processing Record 13 of Set 5 | victoria
# Processing Record 14 of Set 5 | bubaque
# Processing Record 15 of Set 5 | constitucion
# Processing Record 16 of Set 5 | longyearbyen
# Processing Record 17 of Set 5 | onega
# Processing Record 18 of Set 5 | bandarbeyla
# Processing Record 19 of Set 5 | husavik
# Processing Record 20 of Set 5 | balabac
# Processing Record 21 of Set 5 | buqayq
# City not found. Skipping ...
# Processing Record 22 of Set 5 | farah
# Processing Record 23 of Set 5 | kuche
# City not found. Skipping ...
# Processing Record 24 of Set 5 | ukiah
# Processing Record 25 of Set 5 | ubinskoye
# Processing Record 26 of Set 5 | salina cruz
# Processing Record 27 of Set 5 | tuttlingen
# Processing Record 28 of Set 5 | nuuk
# Processing Record 29 of Set 5 | saleaula
# City not found. Skipping ...
# Processing Record 30 of Set 5 | bethel
# Processing Record 31 of Set 5 | aflu
# City not found. Skipping ...
# Processing Record 32 of Set 5 | clyde river
# Processing Record 33 of Set 5 | zhuanghe
# Processing Record 34 of Set 5 | mount gambier
# Processing Record 35 of Set 5 | san quintin
# Processing Record 36 of Set 5 | houma
# Processing Record 37 of Set 5 | palasa
# Processing Record 38 of Set 5 | lazarev
# Processing Record 39 of Set 5 | hofn
# Processing Record 40 of Set 5 | acarau
# Processing Record 41 of Set 5 | manga
# Processing Record 42 of Set 5 | jalingo
# Processing Record 43 of Set 5 | tiksi
# Processing Record 44 of Set 5 | kaputa
# Processing Record 45 of Set 5 | bundaberg
# Processing Record 46 of Set 5 | gizo
# Processing Record 47 of Set 5 | walvis bay
# Processing Record 48 of Set 5 | loralai
# Processing Record 49 of Set 5 | nalut
# Processing Record 50 of Set 5 | cuauhtemoc
# Processing Record 1 of Set 6 | ilulissat
# Processing Record 2 of Set 6 | sentyabrskiy
# City not found. Skipping ...
# Processing Record 3 of Set 6 | maniitsoq
# Processing Record 4 of Set 6 | mahibadhoo
# Processing Record 5 of Set 6 | severobaykalsk
# Processing Record 6 of Set 6 | faya
# Processing Record 7 of Set 6 | cherskiy
# Processing Record 8 of Set 6 | libertador general san martin
# Processing Record 9 of Set 6 | qaqortoq
# Processing Record 10 of Set 6 | benguela
# Processing Record 11 of Set 6 | ust-ilimsk
# Processing Record 12 of Set 6 | hasaki
# Processing Record 13 of Set 6 | palmas
# Processing Record 14 of Set 6 | donauworth
# Processing Record 15 of Set 6 | lakatoro
# Processing Record 16 of Set 6 | mastic beach
# Processing Record 17 of Set 6 | kaseda
# Processing Record 18 of Set 6 | vostok
# Processing Record 19 of Set 6 | geraldton
# Processing Record 20 of Set 6 | cap malheureux
# Processing Record 21 of Set 6 | whitehorse
# Processing Record 22 of Set 6 | palabuhanratu
# City not found. Skipping ...
# Processing Record 23 of Set 6 | qasigiannguit
# Processing Record 24 of Set 6 | padang
# Processing Record 25 of Set 6 | broome
# Processing Record 26 of Set 6 | umm lajj
# Processing Record 27 of Set 6 | souillac
# Processing Record 28 of Set 6 | mayor pablo lagerenza
# Processing Record 29 of Set 6 | deputatskiy
# Processing Record 30 of Set 6 | brewster
# Processing Record 31 of Set 6 | viligili
# City not found. Skipping ...
# Processing Record 32 of Set 6 | la ronge
# Processing Record 33 of Set 6 | xining
# Processing Record 34 of Set 6 | marawi
# Processing Record 35 of Set 6 | markdale
# Processing Record 36 of Set 6 | ginda
# Processing Record 37 of Set 6 | mkushi
# Processing Record 38 of Set 6 | sharjah
# Processing Record 39 of Set 6 | tarauaca
# Processing Record 40 of Set 6 | stoyba
# City not found. Skipping ...
# Processing Record 41 of Set 6 | yarada
# Processing Record 42 of Set 6 | conakry
# Processing Record 43 of Set 6 | tanggu
# Processing Record 44 of Set 6 | shchelyayur
# City not found. Skipping ...
# Processing Record 45 of Set 6 | katsuura
# Processing Record 46 of Set 6 | mumford
# Processing Record 47 of Set 6 | srandakan
# Processing Record 48 of Set 6 | haines junction
# Processing Record 49 of Set 6 | srednekolymsk
# Processing Record 50 of Set 6 | mrirt
# City not found. Skipping ...
# Processing Record 1 of Set 7 | oktyabrskiy
# Processing Record 2 of Set 7 | manono
# Processing Record 3 of Set 7 | iskateley
# Processing Record 4 of Set 7 | babylon
# Processing Record 5 of Set 7 | fortuna
# Processing Record 6 of Set 7 | gurskoye
# City not found. Skipping ...
# Processing Record 7 of Set 7 | kyzyl-suu
# Processing Record 8 of Set 7 | yugorsk
# Processing Record 9 of Set 7 | great yarmouth
# Processing Record 10 of Set 7 | cravo norte
# Processing Record 11 of Set 7 | ginir
# Processing Record 12 of Set 7 | kamenskoye
# City not found. Skipping ...
# Processing Record 13 of Set 7 | paradwip
# City not found. Skipping ...
# Processing Record 14 of Set 7 | cabo san lucas
# Processing Record 15 of Set 7 | birao
# Processing Record 16 of Set 7 | cockburn town
# Processing Record 17 of Set 7 | codrington
# Processing Record 18 of Set 7 | valdivia
# Processing Record 19 of Set 7 | beaverlodge
# Processing Record 20 of Set 7 | springdale
# Processing Record 21 of Set 7 | praya
# Processing Record 22 of Set 7 | ilhabela
# Processing Record 23 of Set 7 | mopipi
# Processing Record 24 of Set 7 | russell
# Processing Record 25 of Set 7 | hudson bay
# Processing Record 26 of Set 7 | hastings
# Processing Record 27 of Set 7 | sangar
# Processing Record 28 of Set 7 | mweka
# Processing Record 29 of Set 7 | nuqui
# Processing Record 30 of Set 7 | ovsyanka
# Processing Record 31 of Set 7 | lompoc
# Processing Record 32 of Set 7 | rawson
# Processing Record 33 of Set 7 | adwa
# Processing Record 34 of Set 7 | sao joao da barra
# Processing Record 35 of Set 7 | sestri levante
# Processing Record 36 of Set 7 | teknaf
# Processing Record 37 of Set 7 | middelburg
# Processing Record 38 of Set 7 | magalia
# Processing Record 39 of Set 7 | pujili
# Processing Record 40 of Set 7 | akdepe
# Processing Record 41 of Set 7 | paka
# Processing Record 42 of Set 7 | kapustin yar
# Processing Record 43 of Set 7 | omboue
# Processing Record 44 of Set 7 | hobyo
# Processing Record 45 of Set 7 | bur gabo
# City not found. Skipping ...
# Processing Record 46 of Set 7 | kidodi
# Processing Record 47 of Set 7 | asau
# Processing Record 48 of Set 7 | howard springs
# Processing Record 49 of Set 7 | port hedland
# Processing Record 50 of Set 7 | comodoro rivadavia
# Processing Record 1 of Set 8 | george
# Processing Record 2 of Set 8 | port blair
# Processing Record 3 of Set 8 | viedma
# Processing Record 4 of Set 8 | jacqueville
# Processing Record 5 of Set 8 | kalat
# Processing Record 6 of Set 8 | rio grande
# Processing Record 7 of Set 8 | llanelli
# Processing Record 8 of Set 8 | palmeiras de goias
# Processing Record 9 of Set 8 | yenagoa
# Processing Record 10 of Set 8 | santa lucia
# Processing Record 11 of Set 8 | polyarnyy
# Processing Record 12 of Set 8 | avera
# Processing Record 13 of Set 8 | medicine hat
# Processing Record 14 of Set 8 | yelnya
# Processing Record 15 of Set 8 | pochutla
# Processing Record 16 of Set 8 | bhuban
# Processing Record 17 of Set 8 | bud
# Processing Record 18 of Set 8 | mogadishu
# Processing Record 19 of Set 8 | rio gallegos
# Processing Record 20 of Set 8 | degtyarsk
# Processing Record 21 of Set 8 | nanortalik
# Processing Record 22 of Set 8 | laguna
# Processing Record 23 of Set 8 | turayf
# Processing Record 24 of Set 8 | namibe
# Processing Record 25 of Set 8 | ponta grossa
# Processing Record 26 of Set 8 | shalakusha
# Processing Record 27 of Set 8 | karauzyak
# City not found. Skipping ...
# Processing Record 28 of Set 8 | henties bay
# Processing Record 29 of Set 8 | vera cruz
# Processing Record 30 of Set 8 | sao filipe
# Processing Record 31 of Set 8 | carballo
# Processing Record 32 of Set 8 | hambantota
# Processing Record 33 of Set 8 | kruisfontein
# Processing Record 34 of Set 8 | harper
# Processing Record 35 of Set 8 | fare
# Processing Record 36 of Set 8 | san jose
# Processing Record 37 of Set 8 | thai binh
# Processing Record 38 of Set 8 | moose factory
# Processing Record 39 of Set 8 | iracoubo
# Processing Record 40 of Set 8 | salalah
# Processing Record 41 of Set 8 | svetlogorsk
# Processing Record 42 of Set 8 | inta
# Processing Record 43 of Set 8 | urupes
# Processing Record 44 of Set 8 | ust-tsilma
# Processing Record 45 of Set 8 | ahipara
# Processing Record 46 of Set 8 | vyazemskiy
# Processing Record 47 of Set 8 | phuket
# Processing Record 48 of Set 8 | palmares
# Processing Record 49 of Set 8 | togur
# Processing Record 50 of Set 8 | mendahara
# City not found. Skipping ...
# Processing Record 1 of Set 9 | rongcheng
# Processing Record 2 of Set 9 | takestan
# Processing Record 3 of Set 9 | cotonou
# Processing Record 4 of Set 9 | eureka
# Processing Record 5 of Set 9 | grand gaube
# Processing Record 6 of Set 9 | vanimo
# Processing Record 7 of Set 9 | tiznit
# Processing Record 8 of Set 9 | tuatapere
# Processing Record 9 of Set 9 | pimenteiras
# Processing Record 10 of Set 9 | cururupu
# Processing Record 11 of Set 9 | ulaanbaatar
# Processing Record 12 of Set 9 | artyk
# City not found. Skipping ...
# Processing Record 13 of Set 9 | port-cartier
# Processing Record 14 of Set 9 | price
# Processing Record 15 of Set 9 | pecos
# Processing Record 16 of Set 9 | bilma
# Processing Record 17 of Set 9 | tavda
# Processing Record 18 of Set 9 | sapernoye
# Processing Record 19 of Set 9 | moyale
# Processing Record 20 of Set 9 | ijaki
# City not found. Skipping ...
# Processing Record 21 of Set 9 | izhma
# Processing Record 22 of Set 9 | necochea
# Processing Record 23 of Set 9 | kaeo
# Processing Record 24 of Set 9 | watsa
# Processing Record 25 of Set 9 | imeni stepana razina
# Processing Record 26 of Set 9 | borogontsy
# Processing Record 27 of Set 9 | kjollefjord
# Processing Record 28 of Set 9 | paamiut
# Processing Record 29 of Set 9 | synya
# Processing Record 30 of Set 9 | klaksvik
# Processing Record 31 of Set 9 | jingcheng
# Processing Record 32 of Set 9 | ancud
# Processing Record 33 of Set 9 | ostrovnoy
# Processing Record 34 of Set 9 | ketchikan
# Processing Record 35 of Set 9 | nara
# Processing Record 36 of Set 9 | ambilobe
# Processing Record 37 of Set 9 | taywarah
# Processing Record 38 of Set 9 | pingzhuang
# Processing Record 39 of Set 9 | adeje
# Processing Record 40 of Set 9 | ourossogui
# Processing Record 41 of Set 9 | vao
# Processing Record 42 of Set 9 | chantilly
# Processing Record 43 of Set 9 | saryshagan
# City not found. Skipping ...
# Processing Record 44 of Set 9 | dakoro
# Processing Record 45 of Set 9 | skegness
# Processing Record 46 of Set 9 | rach gia
# Processing Record 47 of Set 9 | pisco
# Processing Record 48 of Set 9 | shimoda
# Processing Record 49 of Set 9 | lusambo
# Processing Record 50 of Set 9 | whyalla
# Processing Record 1 of Set 10 | petilia policastro
# Processing Record 2 of Set 10 | jibuti
# Processing Record 3 of Set 10 | salto
# Processing Record 4 of Set 10 | karratha
# Processing Record 5 of Set 10 | tessalit
# Processing Record 6 of Set 10 | sorland
# Processing Record 7 of Set 10 | yuncheng
# Processing Record 8 of Set 10 | kanlagay
# Processing Record 9 of Set 10 | margate
# Processing Record 10 of Set 10 | bolungarvik
# City not found. Skipping ...
# Processing Record 11 of Set 10 | rawannawi
# City not found. Skipping ...
# Processing Record 12 of Set 10 | zhezkazgan
# Processing Record 13 of Set 10 | luanda
# Processing Record 14 of Set 10 | fort frances
# Processing Record 15 of Set 10 | denpasar
# Processing Record 16 of Set 10 | honningsvag
# Processing Record 17 of Set 10 | galle
# Processing Record 18 of Set 10 | abu kamal
# Processing Record 19 of Set 10 | nemuro
# Processing Record 20 of Set 10 | tahe
# Processing Record 21 of Set 10 | mayo
# Processing Record 22 of Set 10 | sorvag
# City not found. Skipping ...
# Processing Record 23 of Set 10 | yatou
# Processing Record 24 of Set 10 | clevelandia
# Processing Record 25 of Set 10 | kermanshah
# Processing Record 26 of Set 10 | ruatoria
# City not found. Skipping ...
# Processing Record 27 of Set 10 | louisbourg
# City not found. Skipping ...
# Processing Record 28 of Set 10 | glace bay
# Processing Record 29 of Set 10 | issoire
# Processing Record 30 of Set 10 | abha
# Processing Record 31 of Set 10 | roald
# Processing Record 32 of Set 10 | thabazimbi
# Processing Record 33 of Set 10 | yerbogachen
# Processing Record 34 of Set 10 | coffs harbour
# Processing Record 35 of Set 10 | puri
# Processing Record 36 of Set 10 | agirish
# Processing Record 37 of Set 10 | waipawa
# Processing Record 38 of Set 10 | grindavik
# Processing Record 39 of Set 10 | pacifica
# Processing Record 40 of Set 10 | northam
# Processing Record 41 of Set 10 | chifeng
# Processing Record 42 of Set 10 | attawapiskat
# City not found. Skipping ...
# Processing Record 43 of Set 10 | cabo rojo
# Processing Record 44 of Set 10 | asyut
# Processing Record 45 of Set 10 | mulanje
# Processing Record 46 of Set 10 | muisne
# Processing Record 47 of Set 10 | tuskegee
# Processing Record 48 of Set 10 | san jeronimo
# Processing Record 49 of Set 10 | sinnamary
# Processing Record 50 of Set 10 | marienburg
# Processing Record 1 of Set 11 | berbera
# Processing Record 2 of Set 11 | aldan
# Processing Record 3 of Set 11 | caravelas
# Processing Record 4 of Set 11 | fereydun kenar
# Processing Record 5 of Set 11 | monrovia
# Processing Record 6 of Set 11 | higuey
# City not found. Skipping ...
# Processing Record 7 of Set 11 | chilca
# Processing Record 8 of Set 11 | port moresby
# Processing Record 9 of Set 11 | kalmunai
# Processing Record 10 of Set 11 | terra rica
# Processing Record 11 of Set 11 | manati
# Processing Record 12 of Set 11 | araouane
# Processing Record 13 of Set 11 | tres lagoas
# Processing Record 14 of Set 11 | razole
# Processing Record 15 of Set 11 | verkh-usugli
# Processing Record 16 of Set 11 | atar
# Processing Record 17 of Set 11 | axim
# Processing Record 18 of Set 11 | yulara
# Processing Record 19 of Set 11 | tandil
# Processing Record 20 of Set 11 | nikolayevsk-na-amure
# Processing Record 21 of Set 11 | kutum
# Processing Record 22 of Set 11 | ilo
# Processing Record 23 of Set 11 | thinadhoo
# Processing Record 24 of Set 11 | key west
# Processing Record 25 of Set 11 | tazmalt
# Processing Record 26 of Set 11 | sechura
# Processing Record 27 of Set 11 | goderich
# Processing Record 28 of Set 11 | barcelos
# Processing Record 29 of Set 11 | road town
# Processing Record 30 of Set 11 | caborca
# Processing Record 31 of Set 11 | lazaro cardenas
# Processing Record 32 of Set 11 | kavaratti
# Processing Record 33 of Set 11 | alice springs
# Processing Record 34 of Set 11 | flin flon
# Processing Record 35 of Set 11 | norman wells
# Processing Record 36 of Set 11 | rincon de la victoria
# Processing Record 37 of Set 11 | statesboro
# Processing Record 38 of Set 11 | itarema
# Processing Record 39 of Set 11 | xam nua
# Processing Record 40 of Set 11 | dolores
# Processing Record 41 of Set 11 | morena
# Processing Record 42 of Set 11 | beitbridge
# Processing Record 43 of Set 11 | gawler
# Processing Record 44 of Set 11 | arrecife
# Processing Record 45 of Set 11 | paranapanema
# Processing Record 46 of Set 11 | boyolangu
# Processing Record 47 of Set 11 | curup
# Processing Record 48 of Set 11 | la asuncion
# Processing Record 49 of Set 11 | sur
# Processing Record 50 of Set 11 | okhotsk
# Processing Record 1 of Set 12 | mildura
# Processing Record 2 of Set 12 | tateyama
# Processing Record 3 of Set 12 | tadine
# Processing Record 4 of Set 12 | porto walter
# Processing Record 5 of Set 12 | cervo
# Processing Record 6 of Set 12 | chechat
# Processing Record 7 of Set 12 | shangqiu
# Processing Record 8 of Set 12 | smithers
# Processing Record 9 of Set 12 | naantali
# Processing Record 10 of Set 12 | culebra
# Processing Record 11 of Set 12 | port hardy
# Processing Record 12 of Set 12 | kroya
# Processing Record 13 of Set 12 | sibolga
# Processing Record 14 of Set 12 | zarubino
# Processing Record 15 of Set 12 | fairlie
# Processing Record 16 of Set 12 | sola
# Processing Record 17 of Set 12 | bloemhof
# Processing Record 18 of Set 12 | sukumo
# Processing Record 19 of Set 12 | san fernando
# Processing Record 20 of Set 12 | krasnoselkup
# Processing Record 21 of Set 12 | winslow
# Processing Record 22 of Set 12 | kindu
# Processing Record 23 of Set 12 | delmenhorst
# Processing Record 24 of Set 12 | touros
# Processing Record 25 of Set 12 | guadalupe
# Processing Record 26 of Set 12 | kotaparh
# Processing Record 27 of Set 12 | byron bay
# Processing Record 28 of Set 12 | mujiayingzi
# Processing Record 29 of Set 12 | nador
# Processing Record 30 of Set 12 | kemijarvi
# Processing Record 31 of Set 12 | darab
# Processing Record 32 of Set 12 | saint albans
# Processing Record 33 of Set 12 | anadyr
# Processing Record 34 of Set 12 | tual
# Processing Record 35 of Set 12 | portland
# Processing Record 36 of Set 12 | hualmay
# Processing Record 37 of Set 12 | san luis
# Processing Record 38 of Set 12 | canico
# Processing Record 39 of Set 12 | orlik
# Processing Record 40 of Set 12 | shumskiy
# Processing Record 41 of Set 12 | saint-pierre
# Processing Record 42 of Set 12 | godfrey
# Processing Record 43 of Set 12 | camacha
# Processing Record 44 of Set 12 | gandajika
# Processing Record 45 of Set 12 | tommot
# Processing Record 46 of Set 12 | lodeynoye pole
# Processing Record 47 of Set 12 | shingu
# Processing Record 48 of Set 12 | warqla
# City not found. Skipping ...
# Processing Record 49 of Set 12 | lamu
# Processing Record 50 of Set 12 | kahului
# Processing Record 1 of Set 13 | timra
# Processing Record 2 of Set 13 | aksarka
# Processing Record 3 of Set 13 | krapina
# Processing Record 4 of Set 13 | oussouye
# Processing Record 5 of Set 13 | kingsport
# Processing Record 6 of Set 13 | syracuse
# Processing Record 7 of Set 13 | hwange
# Processing Record 8 of Set 13 | beian
# Processing Record 9 of Set 13 | payo
# Processing Record 10 of Set 13 | mount isa
# Processing Record 11 of Set 13 | foumban
# Processing Record 12 of Set 13 | severo-yeniseyskiy
# Processing Record 13 of Set 13 | den helder
# Processing Record 14 of Set 13 | poltar
# Processing Record 15 of Set 13 | deer lake
# Processing Record 16 of Set 13 | bahia blanca
# Processing Record 17 of Set 13 | san ignacio
# Processing Record 18 of Set 13 | ust-kamchatsk
# City not found. Skipping ...
# Processing Record 19 of Set 13 | obra
# Processing Record 20 of Set 13 | keti bandar
# Processing Record 21 of Set 13 | vestmannaeyjar
# Processing Record 22 of Set 13 | hammerfest
# Processing Record 23 of Set 13 | ambunti
# Processing Record 24 of Set 13 | salisbury
# Processing Record 25 of Set 13 | umzimvubu
# City not found. Skipping ...
# Processing Record 26 of Set 13 | ebnat-kappel
# Processing Record 27 of Set 13 | polovinnoye
# Processing Record 28 of Set 13 | svetlyy
# Processing Record 29 of Set 13 | guerrero negro
# Processing Record 30 of Set 13 | nogliki
# Processing Record 31 of Set 13 | zolotkovo
# Processing Record 32 of Set 13 | nabire
# Processing Record 33 of Set 13 | sussex
# Processing Record 34 of Set 13 | tupancireta
# Processing Record 35 of Set 13 | carolina
# Processing Record 36 of Set 13 | gobabis
# Processing Record 37 of Set 13 | rungata
# City not found. Skipping ...
# Processing Record 38 of Set 13 | alta floresta
# Processing Record 39 of Set 13 | xilopolis
# Processing Record 40 of Set 13 | assens
# Processing Record 41 of Set 13 | monte san giovanni campano
# Processing Record 42 of Set 13 | vardo
# Processing Record 43 of Set 13 | olga
# Processing Record 44 of Set 13 | san juan
# Processing Record 45 of Set 13 | manokwari
# Processing Record 46 of Set 13 | kupang
# Processing Record 47 of Set 13 | kropotkin
# Processing Record 48 of Set 13 | davila
# Processing Record 49 of Set 13 | burnie
# Processing Record 50 of Set 13 | mayskiy
# Processing Record 1 of Set 14 | gold coast
# Processing Record 2 of Set 14 | ottawa
# Processing Record 3 of Set 14 | te anau
# Processing Record 4 of Set 14 | yibin
# Processing Record 5 of Set 14 | nioro
# Processing Record 6 of Set 14 | labuhan
# Processing Record 7 of Set 14 | puerto el triunfo
# Processing Record 8 of Set 14 | tabasco
# Processing Record 9 of Set 14 | ballina
# Processing Record 10 of Set 14 | epe
# Processing Record 11 of Set 14 | mitu
# Processing Record 12 of Set 14 | sawtell
# Processing Record 13 of Set 14 | uwayl
# City not found. Skipping ...
# Processing Record 14 of Set 14 | newnan
# Processing Record 15 of Set 14 | katobu
# Processing Record 16 of Set 14 | matara
# Processing Record 17 of Set 14 | soyo
# Processing Record 18 of Set 14 | beloha
# Processing Record 19 of Set 14 | saurimo
# Processing Record 20 of Set 14 | preston
# Processing Record 21 of Set 14 | juneau
# Processing Record 22 of Set 14 | ipoh
# Processing Record 23 of Set 14 | the valley
# Processing Record 24 of Set 14 | nuzvid
# Processing Record 25 of Set 14 | ola
# Processing Record 26 of Set 14 | ust-maya
# Processing Record 27 of Set 14 | awjilah
# Processing Record 28 of Set 14 | ashqelon
# Processing Record 29 of Set 14 | nizhniy kuranakh
# Processing Record 30 of Set 14 | realeza
# Processing Record 31 of Set 14 | mehamn
# Processing Record 32 of Set 14 | labytnangi
# Processing Record 33 of Set 14 | sistranda
# Processing Record 34 of Set 14 | jevargi
# Processing Record 35 of Set 14 | madimba
# Processing Record 36 of Set 14 | kirakira
# Processing Record 37 of Set 14 | xichang
# Processing Record 38 of Set 14 | pizarro
# Processing Record 39 of Set 14 | calbuco
# Processing Record 40 of Set 14 | tabas
# Processing Record 41 of Set 14 | suntar
# Processing Record 42 of Set 14 | gandai
# Processing Record 43 of Set 14 | bonavista
# Processing Record 44 of Set 14 | port lincoln
# Processing Record 45 of Set 14 | dzaoudzi
# Processing Record 46 of Set 14 | sibu
# Processing Record 47 of Set 14 | tanda
# Processing Record 48 of Set 14 | safwah
# City not found. Skipping ...
# Processing Record 49 of Set 14 | los llanos de aridane
# Processing Record 50 of Set 14 | havoysund
# Processing Record 1 of Set 15 | jiddah
# City not found. Skipping ...
# Processing Record 2 of Set 15 | shagonar
# Processing Record 3 of Set 15 | saint-louis
# Processing Record 4 of Set 15 | poum
# Processing Record 5 of Set 15 | tafresh
# Processing Record 6 of Set 15 | makhinjauri
# Processing Record 7 of Set 15 | kapoeta
# Processing Record 8 of Set 15 | grand island
# Processing Record 9 of Set 15 | samusu
# City not found. Skipping ...
# Processing Record 10 of Set 15 | acapulco
# Processing Record 11 of Set 15 | mnogovershinnyy
# Processing Record 12 of Set 15 | beira
# Processing Record 13 of Set 15 | babol
# Processing Record 14 of Set 15 | bairiki
# Processing Record 15 of Set 15 | lugovoy
# Processing Record 16 of Set 15 | cascais
# Processing Record 17 of Set 15 | buala
# Processing Record 18 of Set 15 | galveston
# Processing Record 19 of Set 15 | birjand
# Processing Record 20 of Set 15 | villarrica
# Processing Record 21 of Set 15 | derbent
# Processing Record 22 of Set 15 | chabahar
# Processing Record 23 of Set 15 | zamora
# Processing Record 24 of Set 15 | cedar city
# Processing Record 25 of Set 15 | yangambi
# Processing Record 26 of Set 15 | uk
# City not found. Skipping ...
# Processing Record 27 of Set 15 | pucallpa
# Processing Record 28 of Set 15 | umm kaddadah
# Processing Record 29 of Set 15 | yirol
# City not found. Skipping ...
# Processing Record 30 of Set 15 | falealupo
# City not found. Skipping ...
# Processing Record 31 of Set 15 | alanya
# Processing Record 32 of Set 15 | macrohon
# Processing Record 33 of Set 15 | chimbote
# Processing Record 34 of Set 15 | bismil
# Processing Record 35 of Set 15 | hami
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %%
len(city_data)
# Out:
# 681

# %%
city_data_df=pd.DataFrame(city_data)

# %%
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

city_data_df=city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mahebourg      MU -20.4081   57.7000     68.29       100          75
# 1      High Level      CA  58.5169 -117.1360     60.91        82          75
# 2           Moron      AR -34.6534  -58.6198     49.75        68          10
# 3  Saint-Philippe      RE -21.3585   55.7679     63.99        82          36
# 4    Saint George      US  37.1041 -113.5841    102.79         7           0
# 5       Egvekinot      RU  66.3167 -179.1667     40.95        47          73
# 6         Kavieng      PG  -2.5744  150.7967     85.37        66          43
# 7         Mataura      NZ -46.1927  168.8643     47.48        90          99
# 8         Ushuaia      AR -54.8000  -68.3000     49.66        76          75
# 9           Zabid      YE  14.1951   43.3152     86.70        56         100
#
#    Wind Speed Current Description
# 0        3.44          light rain
# 1        2.30       broken clouds
# 2        4.41           clear sky
# 3       12.24          light rain
# 4       12.66           clear sky
# 5        3.15       broken clouds
# 6       13.18    scattered clouds
# 7        3.69          light rain
# 8        8.05       broken clouds
# 9        5.75     overcast clouds

# %%
output_data_file="Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
